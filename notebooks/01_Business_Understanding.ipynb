# %% [markdown]
# # 1. Business Understanding
#
# ### Proyecto Parcial — MLY0100
# **Autor:** Antonio Sepúlveda
# **Fecha:** 2025
#
# ---
#
# # 🩺 Contexto del Proyecto
# La diabetes es una de las enfermedades crónicas más críticas a nivel mundial. La capacidad de anticipar si un paciente tiene riesgo de presentar diabetes permite:
#
# - Intervenir tempranamente.
# - Prevenir complicaciones.
# - Reducir costos en el sistema de salud.
# - Priorizar pacientes de alto riesgo.
#
# Este proyecto implementa un **pipeline de Machine Learning con Kedro**, capaz de procesar automáticamente el dataset, entrenar modelos, evaluarlos y generar reportes.
#
# ---
# # 🎯 Objetivo del Proyecto
# Desarrollar un **sistema automatizado** que permita:
#
# ### ✔️ Clasificar pacientes con o sin diabetes
# - 0 = No diabetes
# - 1 = Diabetes
#
# ### ✔️ Automatizar el flujo completo mediante Kedro
# - Limpieza de datos
# - Preprocesamiento
# - División train/test
# - Entrenamiento de modelos
# - Evaluación
# - Visualización
# - Reportes automáticos en `data/08_reporting/`
#
# ---
# # 📌 Importancia del Proyecto
#
# **Para profesionales de salud y analistas**, este pipeline permite:
# - Identificar factores más relevantes en la aparición de diabetes.
# - Entregar predicciones rápidas y confiables.
# - Generar visualizaciones estandarizadas.
# - Integrarse a sistemas como Docker o Airflow para automatización programada.
#
# ---
# # 🧱 Componentes del pipeline
#
# El pipeline está compuesto por:
#
# ### 🔹 1. Limpieza y tratamiento de datos
# - Imputación de valores
# - Manejo de outliers
# - Normalización
#
# ### 🔹 2. División Train/Test
# Permite separar datos para entrenamiento y evaluación realista.
#
# ### 🔹 3. Entrenamiento de modelo ML
# Modelo principal: **RandomForestClassifier**.
#
# ### 🔹 4. Evaluación
# - Accuracy
# - MSE
# - Precision / Recall
# - Matriz de confusión
#
# ### 🔹 5. Reportes automáticos
# Se guardan en `data/08_reporting/`.
#
# ---
# # 📦 Dataset utilizado
# El proyecto usa el dataset **PIMA Diabetes Dataset**, ubicado en:
#
# `data/01_raw/diabetes.csv`
#
# Variables más relevantes incluyen:
# - Glucose
# - BloodPressure
# - SkinThickness
# - Insulin
# - BMI
# - Age
# - DiabetesPedigreeFunction
#
# ---
# # ✔️ Conclusiones iniciales
# - El proyecto sigue una estructura profesional bajo Kedro.
# - Permite ejecución reproducible, escalable y mantenible.
# - Tiene utilidad directa para predicción clínica.
#
# ---
# ### **➡️ Siguiente Notebook: 2_Data_Understanding.ipynb**
