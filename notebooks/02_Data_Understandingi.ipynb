# %% [markdown]
# # 2. Data Understanding
#
# ### Proyecto Parcial — MLY0100
# **Autor:** Antonio Sepúlveda
# **Fecha:** 2025
#
# ---
# # 🎯 Objetivo del notebook
# En este notebook se analiza el dataset de **diabetes** utilizado por el pipeline de Kedro.
# Buscamos entender:
# - La estructura de los datos
# - Las distribuciones de variables
# - Posibles valores faltantes
# - Presencia de outliers
# - Relaciones entre variables y la variable objetivo `Outcome`
#
# Esto permitirá definir mejor las decisiones de preprocesamiento y modelado.

# %% [markdown]
# ## 1. Carga del dataset
# El archivo crudo se encuentra en la ruta:
# `data/01_raw/diabetes.csv` (desde la carpeta del proyecto Kedro, este notebook lo lee con ruta relativa `../data/01_raw/diabetes.csv`).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('default')

# Cargar dataset crudo
df = pd.read_csv('../data/01_raw/diabetes.csv')

df.head()

# %% [markdown]
# ## 2. Dimensiones y tipos de datos
# Revisamos el tamaño del dataset y los tipos de variables disponibles.

# %%
print(f"Filas: {df.shape[0]}")
print(f"Columnas: {df.shape[1]}\n")

df.info()

# %% [markdown]
# ## 3. Estadísticas descriptivas
# Obtenemos estadísticos básicos (media, mediana, desviación estándar, mínimos y máximos) para las variables numéricas.

# %%
df.describe().T

# %% [markdown]
# ## 4. Distribución de variables numéricas
# Visualizamos los histogramas de todas las variables numéricas para identificar sesgos y posibles valores extremos.

# %%
df.hist(figsize=(12, 8), bins=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Matriz de correlación
# Revisamos la correlación entre variables numéricas, especialmente con la variable objetivo `Outcome`.

# %%
plt.figure(figsize=(10, 8))
corr = df.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Matriz de correlación - Dataset Diabetes')
plt.show()

# %% [markdown]
# ## 6. Revisión de valores faltantes
# Verificamos si hay valores nulos explícitos en el dataset.

# %%
missing_counts = df.isnull().sum()
missing_counts[missing_counts > 0]

# %% [markdown]
# En varios casos, el dataset de diabetes no tiene `NaN` explícitos, pero puede representar valores faltantes con ceros en variables como **Glucose**, **BloodPressure**, **SkinThickness**, **Insulin** o **BMI**.
# Esto se considerará en la etapa de **preparación de datos**.

# %% [markdown]
# ## 7. Detección rápida de outliers
# Generamos boxplots para algunas variables clave.

# %%
plt.figure(figsize=(12, 6))
cols = ['Glucose', 'BloodPressure', 'BMI', 'Age']
df[cols].boxplot()
plt.title('Boxplots de variables clave')
plt.show()

# %% [markdown]
# ## 8. Distribución de la variable objetivo `Outcome`
# Revisamos el balance de clases (0 = no diabetes, 1 = diabetes).

# %%
outcome_counts = df['Outcome'].value_counts()
print(outcome_counts)

plt.figure(figsize=(4, 4))
sns.countplot(x='Outcome', data=df)
plt.title('Distribución de Outcome (0 = No, 1 = Sí)')
plt.show()

# %% [markdown]
# ---
# ## ✅ Conclusiones del Data Understanding
# - El dataset contiene variables clínicas relevantes (Glucose, BMI, Age, etc.) vinculadas a la aparición de diabetes.
# - La variable objetivo `Outcome` está desbalanceada de forma moderada (más casos sin diabetes que con diabetes).
# - No se observan valores nulos explícitos, pero algunos ceros deben tratarse como posibles valores faltantes en variables biomédicas.
# - Existen outliers en varias variables, que se abordarán en la fase de **preparación de datos**.
#
# ---
# ➡️ Siguiente paso: `3_Data_Preparation.ipynb` para limpieza, imputación y preparación de los datos antes del modelado.
